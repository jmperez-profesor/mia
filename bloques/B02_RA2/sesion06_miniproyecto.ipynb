# %% [markdown]
# # Miniproyecto · Sesión 06 — Satisfacción de restricciones (CSP)
#
# **Enunciado.** Se debe confeccionar el **horario** de 5 asignaturas en 4 franjas
# horarias. Cada asignatura necesita una franja distinta y hay restricciones de
# profesorado: algunas asignaturas no pueden coincidir en la misma franja. Implementa un
# solver CSP con **backtracking** y heurística **MRV** (variable de mínimo dominio restante).
#
# **Entregables.**
# - Representación de variables, dominios y restricciones binarias.
# - Función `backtracking(asignacion)` con MRV que devuelva una asignación completa o `None`.
# - Impresión del horario resultante y nº de nodos del árbol de búsqueda.
#
# **Criterios de evaluación (RA2/CE6).** El alumno modela un problema real como CSP y
# aplica retroceso con poda/ordenación de variables para resolverlo eficientemente.

# %%
import numpy as np

# --- Datos sintéticos del horario ---
asignaturas = ["IA", "BD", "PROG", "SO", "RED"]
franjas = [1, 2, 3, 4]
# restricción: (a, b) -> no pueden estar en la misma franja (mismo profesor)
incompatibles = [("IA", "BD"), ("PROG", "SO"), ("BD", "RED")]

# TODO 1: comprueba si asignar 'asig' a 'franja' es consistente con lo ya asignado
def consistente(asignacion, asig, franja):
    raise NotImplementedError

# TODO 2: selecciona la siguiente variable por MRV (menor nº de franjas válidas)
def seleccion_mrv(asignacion):
    raise NotImplementedError

# TODO 3: backtracking con MRV; devuelve dict {asig: franja} o None
def backtracking(asignacion=None, nodos=None):
    raise NotImplementedError

sol = backtracking()
print("Solución CSP:", sol)
