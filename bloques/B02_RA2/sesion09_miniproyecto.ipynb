# %% [markdown]
# # Miniproyecto · Sesión 09 — Motores de reglas e inferencia
#
# **Enunciado.** Implementa un **motor de inferencia** por encadenamiento hacia delante
# (forward chaining) en Python puro: partiendo de un conjunto de hechos y un conjunto de
# reglas `SI <condiciones> ENTONCES <conclusión>`, deduce todos los hechos alcanzables.
# Aplícalo a un sistema experto de **diagnóstico** (p.ej. avería de una impresora 3D).
#
# **Entregables.**
# - Motor `encadenar(hechos, reglas)` que devuelva el conjunto cerrado de hechos.
# - Base de conocimiento del dominio elegido (≥ 6 reglas).
# - Traza de las reglas disparadas y diagnóstico final.
#
# **Criterios de evaluación (RA2/CE6).** El alumno separa base de conocimiento y motor de
# inferencia, y explica el ciclo reconocer-actuar y la resolución de conflictos.

# %%
# --- Motor de reglas genérico (forward chaining) ---

# TODO 1: define los hechos iniciales como un conjunto de cadenas
hechos = {
    "sin_calientar",
    "filamento_presente",
    "ruido_extrusion",
}

# TODO 2: define reglas como tuplas (frozenset_condiciones, conclusion)
reglas = [
    # (frozenset({"sin_calientar", "filamento_presente"}), "baja_temperatura_hotend"),
    # ...
]

# TODO 3: implementa el motor de encadenamiento hacia delante
def encadenar(hechos, reglas):
    raise NotImplementedError

nuevos = encadenar(set(hechos), reglas)
print("Hechos deducidos:", sorted(nuevos))
