# %% [markdown]
# # Miniproyecto · Sesión 08 — Programación lógica con Prolog
#
# **Enunciado.** Construye una **base de conocimiento genealógica** en Prolog: hechos
# (`padre/2`, `madre/2`) y reglas derivadas (`abuelo`, `hermano`, `ancestro`). Luego
# formula varias consultas (¿quién es abuelo de quién?, ¿X es ancestro de Y?).
#
# **Entregables.**
# - Programa Prolog (hechos + reglas) en una celda de texto o usando `pyswip`.
# - Al menos 5 consultas resueltas (con `pyswip` o manualmente).
# - Explicación de la resolución por unificación y backtracking de Prolog.
#
# **Criterios de evaluación (RA2/CE6).** El alumno representa conocimiento como hechos y
# reglas lógicas y obtiene respuestas por inferencia automática.
#
# > Nota: la celda de código usa `pyswip`, que requiere SWI-Prolog instalado
# > (`pip install pyswip` y el binario `swipl`). Si no está disponible, trabaja el
# > programa en la celda de texto y razona las consultas a mano.

# %%
# Célula de conocimiento (Prolog). Requiere pyswip + swipl.
from pyswip import Prolog

prolog = Prolog()
# TODO 1: añade los hechos (padre/2, madre/2) de una familia sintética
# prolog.assertz("padre(juan, maria)")
# prolog.assertz("madre(lucia, maria)")
# ...

# TODO 2: define reglas derivadas (abuelo, hermano, ancestro)
# prolog.assertz("abuelo(X,Y) :- padre(X,Z), padre(Z,Y)")
# ...

# TODO 3: lanza consultas y muestra resultados
# for sol in prolog.query("abuelo(X,Y)"):
#     print(sol)
