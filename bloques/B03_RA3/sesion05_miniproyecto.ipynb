# %% [markdown]
# # Miniproyecto · Sesión 05 — Mi primer modelo de lenguaje
#
# **Enunciado:** Diseña un corpus sintético de 15–25 oraciones sobre un tema libre, entrena un
# LM n-grama (unigrama o bigrama) y genera 5 textos, analizando coherencia y limitaciones.
#
# **Entregables:**
# - Notebook con el entrenamiento y la generación.
# - Comentario comparando n-grama con la idea de transformer.
#
# **Criterios de evaluación (CE7):**
# - El LM se entrena sobre corpus propio.
# - La generación es funcional y se analiza críticamente.
# - Se explica la limitación del contexto fijo de los n-gramas.

# %%
from collections import defaultdict, Counter
import random

# TODO: corpus sintetico (lista de oraciones)
oraciones = [
    "hace sol y calor",
    "llueve y hace frio",
]

# TODO: construye el modelo n-grama (unigrama o bigrama)
modelo = defaultdict(Counter)

# TODO: implementa generar(inicio, pasos) y genera 5 textos
def generar(inicio, pasos=5):
    return []
