# %% [markdown]
# # Miniproyecto · Sesión 07 — Diseño de prompts para un caso de uso
#
# **Enunciado:** Elige un caso (atención al cliente, resumen, clasificación) y diseña 3 variantes
# de prompt (básico, con contexto, few-shot), discutiendo cuál es más robusta y qué alucinaciones
# podrían aparecer.
#
# **Entregables:**
# - Notebook con las plantillas de prompt y un análisis escrito.
# - Tabla comparativa de las 3 variantes y riesgos identificados.
#
# **Criterios de evaluación (CE7):**
# - Los prompts son coherentes y aplicables.
# - Se identifican alucinaciones y limitaciones.
# - Se propone una estrategia de mitigación.

# %%
# TODO: define el caso de uso y el rol del asistente
caso = "atencion al cliente de telecomunicaciones"

# TODO: disena 3 variantes de prompt (basico, con contexto, few-shot)
prompt_basico = """
{caso}
Pregunta: {pregunta}
"""

prompt_contexto = """
Eres un asistente de {caso}. Responde en menos de 50 palabras.
Pregunta: {pregunta}
"""

prompt_fewshot = """
Ejemplos:
P: No tengo internet -> R: Reinicie el router y verifique luces.
P: {pregunta} -> R:
"""

# TODO: completa la tabla comparativa y el analisis de alucinaciones
