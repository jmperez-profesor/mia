# %% [markdown]
# # Miniproyecto · Sesión 01 — Radiografía de un corpus propio
#
# **Enunciado:** Selecciona un corpus pequeño y propio (10–20 reseñas, titulares o mensajes) y
# elabora un análisis exploratorio: número de documentos, vocabulario, 10 términos más frecuentes
# y tres observaciones sobre ambigüedad o ruido en los datos.
#
# **Entregables:**
# - Este notebook con el corpus embebido y el análisis.
# - Comentario breve (markdown) interpretando los resultados.
#
# **Criterios de evaluación (CE7):**
# - El corpus es propio y acotado.
# - El análisis es reproducible y los resultados se interpretan.
# - Se identifica al menos una limitación del texto en bruto.

# %%
import re
from collections import Counter

# TODO: sustituye este corpus de ejemplo por el tuyo (lista de strings)
corpus = [
    "El servicio de atencion al cliente fue rapido y eficiente",
    "El producto llego tarde y venia defectuoso",
    "Muy buena relacion calidad precio, lo recomiendo",
    "Pesima experiencia, no volvere a comprar",
]

# TODO: implementa una funcion de tokenizacion basica (minusculas + solo alfabeticos)
def tokenizar(texto):
    # ...
    return []

# TODO: define tus stopwords y filtra
stopwords = set()

# TODO: calcula frecuencias y muestra el top 10
# frecuencias = Counter(...)
# print(frecuencias.most_common(10))
