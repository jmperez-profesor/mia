# %% [markdown]
# # Miniproyecto · Sesión 08 — Proyecto integrador RA3
#
# **Enunciado:** Elige UNA opción y entrega un notebook completo y reproducible:
# 1. Clasificador de sentimiento de un corpus propio (>=20 ejemplos).
# 2. Buscador semántico TF-IDF sobre un corpus propio (>=10 documentos).
# 3. Embeddings de dominio (Word2Vec) sobre un corpus propio (>=30 oraciones).
#
# **Entregables:**
# - Notebook con el pipeline elegido.
# - Sección markdown «Aplicación y limitaciones» (reflexión CE7).
#
# **Criterios de evaluación (CE7):**
# - El corpus es propio y el notebook reproducible.
# - Se aplica correctamente al menos una técnica del bloque.
# - Se evalúa el resultado y se reflexiona sobre aplicaciones y limitaciones del PLN.

# %%
import re
# TODO: elige tu opcion (1 clasificacion / 2 buscador / 3 embeddings)
# TODO: carga/tu corpus propio
# TODO: aplica preprocesado -> representacion -> modelo -> evaluacion
# TODO: anade una celda markdown "Aplicacion y limitaciones" reflexionando sobre CE7

def limpiar(texto):
    texto = re.sub(r"[^a-záéíóúñü\s]", " ", texto.lower())
    return texto

# corpus = [...]
# (implementa el pipeline elegido)
