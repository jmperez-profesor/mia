# %% [markdown]
# # Miniproyecto · Sesión 02 — Limpieza de un corpus de reseñas
#
# **Enunciado:** Construye una función `preprocesar(texto)` reutilizable que aplique limpieza,
# tokenización, filtrado de stopwords y lematización básica sobre 10–20 reseñas sintéticas, y
# reporta cuántos tokens útiles quedan respecto al total.
#
# **Entregables:**
# - Notebook con la función y su aplicación al corpus.
# - Tabla resumen: tokens crudos vs. tokens útiles por documento.
#
# **Criterios de evaluación (CE7):**
# - La función `preprocesar` es modular y reutilizable.
# - Se justifica la eliminación o conservación de stopwords.
# - Se identifica al menos una entidad o categoría relevante.

# %%
import re

# TODO: corpus de reseñas sinteticas (lista de strings)
reseñas = [
    "Apple presentó el iPhone en 2007. Apple es una empresa de tecnología.",
    "Samsung lanzó el Galaxy en Seúl con gran expectación.",
]

stopwords = {"el", "la", "en", "es", "una", "con", "de", "y"}

# TODO: implementa preprocesar(texto) -> lista de tokens limpios
def preprocesar(texto):
    # 1) limpieza 2) tokenizacion 3) stopwords 4) lematizacion basica
    return []

# TODO: aplica y cuenta tokens crudos vs utiles por documento
