# %% [markdown]
# # Miniproyecto · Sesión 03 — Buscador semántico mini
#
# **Enunciado:** Vectoriza un corpus propio de 8–12 documentos cortos con TF-IDF y, dada una
# consulta de prueba, devuelve los 3 documentos más similares usando la similitud del coseno.
#
# **Entregables:**
# - Notebook con la vectorización y la función de búsqueda.
# - Resultados para al menos 2 consultas distintas.
#
# **Criterios de evaluación (CE7):**
# - El corpus se vectoriza correctamente con TF-IDF.
# - La búsqueda devuelve resultados coherentes y se explican.
# - Se comenta la limitación de perder el orden de las palabras.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# TODO: corpus propio (8-12 documentos)
docs = [
    "el gato come pescado en la cocina",
    "el perro corre por el jardin",
    "el coche viaja rapido por la carretera",
]

# TODO: crea el vectorizador y la matriz TF-IDF
# vec = TfidfVectorizer()
# X = vec.fit_transform(docs)

# TODO: implementa buscar(consulta, top_k=3)
def buscar(consulta, top_k=3):
    # calcula similitud del coseno y devuelve los indices y scores
    return []
