# %% [markdown]
# # Miniproyecto · Sesión 06 — IA y eficiencia operativa I
#
# **Enunciado**
# A partir de un registro sintético de operaciones de un almacén (tiempo de proceso,
# ocupación, tipo de operación, número de errores), aplica **clustering (K-Means)** para
# detectar grupos de operaciones ineficientes y una **regresión lineal** para modelar el
# tiempo en función de la carga. Identifica las operaciones con mayor tiempo predicho
# respecto al real (ineficientes).
#
# **Entregables**
# 1. Pipeline de preprocesado + K-Means (k=3) y asignación de clusters.
# 2. Modelo de regresión y métrica R².
# 3. Lista de las 10 operaciones más ineficientes (residual positivo mayor).
#
# **Criterios de evaluación (RA1/CE4)**
# - Se aplica una técnica de IA a un problema operativo realista.
# - Se interpreta el resultado como mejora de eficiencia.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Miniproyecto S6: eficiencia operativa en almacen (datos sinteticos)
np.random.seed(33)
n = 300
carga = np.random.uniform(10, 100, n)
tipo = np.random.randint(0, 3, n)
errores = np.random.poisson(0.3 + carga/200)
# tiempo base + ruido + ineficiencia aleatoria en algunas operaciones
inef = np.random.choice([0, 1], n, p=[0.85, 0.15])
tiempo = 2 + 0.08*carga + 4*inef + np.random.normal(0, 1.5, n)
df = pd.DataFrame({"carga":carga, "tipo":tipo, "errores":errores, "tiempo":tiempo})

# TODO: escala las features y aplica KMeans(k=3); guarda df["cluster"]
# TODO: ajusta LinearRegression(tiempo ~ carga) y calcula R2
# TODO: computa residual = tiempo_real - tiempo_predicho; lista top-10 ineficientes
# TODO: grafica clusters o residuales
