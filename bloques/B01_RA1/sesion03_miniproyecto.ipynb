# %% [markdown]
# # Miniproyecto · Sesión 03 — Arquitecturas de agentes
#
# **Enunciado**
# En un problema logístico sintético (reparto de 8 pedidos en una ciudad de 8 nodos),
# compara tres arquitecturas de agente: (a) **reflejo simple**, (b) **basado en modelo**,
# (c) **orientado a objetivos**. Cada una planifica la ruta con distinto nivel de
# información. Mide coste total (distancia) y tiempo de cómputo.
#
# **Entregables**
# 1. Implementación de las tres arquitecturas sobre el grafo de la ciudad.
# 2. Gráfica de barras comparando coste medio de ruta.
# 3. Justificación de por qué la arquitectura orientada a objetivos mejora al reflejo.
#
# **Criterios de evaluación (RA1/CE4)**
# - Se distinguen los componentes de cada arquitectura (estado, modelo, objetivo).
# - Se argumenta la relación arquitectura→eficiencia operativa.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Miniproyecto S3: arquitecturas de agente en logística
np.random.seed(13)
NODOS = 8

# Matriz de distancias simétrica sintética
distancias = np.random.randint(5, 50, size=(NODOS, NODOS))
np.fill_diagonal(distancias, 0)
distancias = (distancias + distancias.T) // 2
pedidos = [1,3,4,6,2,7,0,5]  # orden de visita "crudo"

# TODO: (a) arquitectura de reflejo simple: ruta = orden de aparicion de pedidos
def ruta_reflejo(pedidos, distancias):
    raise NotImplementedError

# TODO: (b) basada en modelo: usa la matriz para elegir vecino mas cercano no visitado
def ruta_modelo(pedidos, distancias):
    raise NotImplementedError

# TODO: (c) orientada a objetivos: vecino mas cercano pero minimizando regreso al almacen (nodo 0)
def ruta_objetivo(pedidos, distancias):
    raise NotImplementedError

def coste(ruta, distancias):
    # TODO: suma distancias consecutivas (incluye vuelta al nodo 0)
    raise NotImplementedError

# TODO: ejecuta 20 replicas, compara costes medios y grafica
