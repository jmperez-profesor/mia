# %% [markdown]
# # Miniproyecto · Sesión 07 — IA y eficiencia operativa II
#
# **Enunciado**
# Construye un modelo de **previsión de demanda** (regresión) para 12 tiendas sintéticas a
# partir de una serie temporal de 90 días, y calcula el ahorro estimado frente a un
# estock" sobre-stock por regla fija. Compara error de predicción (MAE) y cuantifica la
# reducción de inventario recomendada.
#
# **Entregables**
# 1. Serie temporal sintética y modelo de regresión (ej. RandomForest o lineal con
#    estacionalidad).
# 2. Comparación de MAE: modelo IA vs regla fija de stock.
# 3. Informe de ahorro estimado (% de reducción de inventario sin perder nivel de servicio).
#
# **Criterios de evaluación (RA1/CE4)**
# - Se relaciona la predicción con la eficiencia operativa (coste de inventario).
# - Se cuantifica la mejora aportada por la IA.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Miniproyecto S7: prevision de demanda y eficiencia de inventario
np.random.seed(42)
dias = np.arange(1, 91)
# demanda con tendencia, estacionalidad semanal y ruido
demanda = 50 + 0.3*dias + 10*np.sin(2*np.pi*dias/7) + np.random.normal(0, 5, 90)

df = pd.DataFrame({"dia": dias, "demanda": demanda})
df["dia_semana"] = df["dia"] % 7
df["tendencia"] = df["dia"]

# TODO: divide en train/test (80/20), entrena RandomForestRegressor
# TODO: calcula MAE del modelo y MAE de la "regla fija" (stock = media global)
# TODO: estima ahorro de inventario: reduce stock de la regla fija al p95 predicho
# TODO: grafica demanda real vs prediccion y muestra el ahorro %
