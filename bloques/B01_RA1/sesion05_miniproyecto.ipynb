# %% [markdown]
# # Miniproyecto · Sesión 05 — Sistemas basados en conocimiento en la empresa
#
# **Enunciado**
# Construye un **sistema experto** de triaje de incidencias de TI (nivel 1/2/3 y
# auto-resolución) mediante encadenamiento hacia delante (*forward chaining*) sobre un
# conjunto de reglas IF–THEN. Evalúalo sobre 20 incidencias sintéticas y calcula la tasa
# de auto-resolución y el reparto por nivel.
#
# **Entregables**
# 1. Base de reglas (lista de reglas IF–THEN) y motor de inferencia.
# 2. Evaluación sobre el conjunto sintético de incidencias.
# 3. Gráfica de barras del reparto de incidencias por nivel de soporte.
#
# **Criterios de evaluación (RA1/CE4)**
# - Se identifica cómo un SBC mejora la eficiencia operativa (menos escalado manual).
# - Las reglas son coherentes y el motor las aplica correctamente.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Miniproyecto S5: sistema experto de triaje de incidencias TI
np.random.seed(21)

# Hechos de entrada por incidencia (sintéticos)
incidencias = pd.DataFrame({
    "id": range(1, 21),
    "error_login":      np.random.randint(0,2,20),
    "lentitud":         np.random.randint(0,2,20),
    "software_terceros":np.random.randint(0,2,20),
    "datos_criticos":   np.random.randint(0,2,20),
    "afecta_varios":    np.random.randint(0,2,20),
})

# TODO: define la base de reglas como lista de (condiciones_dict, conclusion)
# Ejemplo: si error_login y no datos_criticos -> "auto_reset"
reglas = [
    # ("auto_reset", {"error_login":1}),
    # ("nivel_1", {"lentitud":1, "software_terceros":0}),
    # ("nivel_2", {"software_terceros":1}),
    # ("nivel_3", {"datos_criticos":1, "afecta_varios":1}),
]

def inferir(fila, reglas):
    # TODO: aplica forward chaining y devuelve la conclusion de mayor nivel
    raise NotImplementedError

# TODO: aplica inferir a todas las incidencias y agrupa por nivel
# TODO: grafica el reparto y calcula % de auto-resolucion
