# %% [markdown]
# # Miniproyecto · Sesión 04 — Representación del conocimiento
#
# **Enunciado**
# Modela el organigrama y las relaciones de una empresa ficticia como **grafo de
# conocimiento** (networkx). Representa empleados, departamentos y relaciones
# (`pertenece_a`, `reporta_a`, `gestiona`). Implementa consultas: "¿quién reporta a X?",
# "¿qué departamento tiene más personal?" y "camino de mando entre A y B".
#
# **Entregables**
# 1. Construcción del grafo con nodos y aristas etiquetadas.
# 2. Tres funciones de consulta sobre el grafo.
# 3. Visualización del grafo con matplotlib.
#
# **Criterios de evaluación (RA1/CE4)**
# - Se eligen esquemas de representación (grafos/relaciones) adecuados.
# - Se razona sobre la información representada.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# Miniproyecto S4: grafo de conocimiento de una empresa
G = nx.DiGraph()

# TODO: añade nodos (empleados E1..E6, departamentos D1..D3)
# TODO: añade aristas con relaciones: pertenece_a, reporta_a, gestiona

def quien_reporta_a(G, nodo):
    # TODO: devuelve lista de nodos que reportan a 'nodo'
    raise NotImplementedError

def departamento_mayor(G):
    # TODO: devuelve el departamento con mas empleados
    raise NotImplementedError

def camino_mando(G, a, b):
    # TODO: devuelve la ruta (si existe) de 'a' a 'b' siguiendo 'reporta_a'
    raise NotImplementedError

# TODO: dibuja el grafo (nx.draw) y muestra los resultados de las consultas
