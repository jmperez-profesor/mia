# %% [markdown]
# # Miniproyecto · Sesión 02 — Agentes y entornos
#
# **Enunciado**
# Implementa y simula un **agente de limpieza (vacuum agent)** en un mundo de rejilla
# sintético de 5x5 con suciedad aleatoria. El agente percibe la casilla actual (limpia/sucia)
# y decide aspirar o moverse. Mide la *performance* como porcentaje de casillas limpias tras
# N pasos y compara un agente aleatorio frente a una heurística simple.
#
# **Entregables**
# 1. Código de la simulación (rejilla, agente, bucle percepto-acción).
# 2. Gráfica de la mejora de performance a lo largo de los pasos.
# 3. Tabla comparando agente aleatorio vs heurístico (media de 10 simulaciones).
#
# **Criterios de evaluación (RA1/CE4)**
# - Se describe el ciclo percepción→decisión→acción del agente.
# - Se relaciona el entorno (observable/determinista) con la estrategia del agente.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Miniproyecto S2: agente de limpieza en rejilla 5x5
np.random.seed(7)
N = 5
PASOS = 50

# TODO: crea la rejilla de suciedad (1=sucia, 0=limpia)
# mundo = np.random.choice([0,1], size=(N,N))

# TODO: define la posición inicial del agente (fila, col)
# agente = [0, 0]

def percibir(mundo, pos):
    # TODO: devuelve si la casilla actual esta sucia
    raise NotImplementedError

def accion_agente_heuristico(mundo, pos):
    # TODO: si sucia -> aspirar; si limpia -> moverse a una vecina sucia o aleatoria
    raise NotImplementedError

def accion_agente_aleatorio(mundo, pos):
    # TODO: elige aleatoriamente entre aspirar o moverse
    raise NotImplementedError

def simular(agente_fn, semilla=0):
    # TODO: ejecuta PASOS iteraciones, actualiza mundo y pos, devuelve lista de % limpio
    raise NotImplementedError

# TODO: compara ambos agentes (10 simulaciones) y grafica la media
# TODO: construye un DataFrame con los resultados y muestralo
