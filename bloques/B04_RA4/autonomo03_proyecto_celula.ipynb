# %% [markdown]
# # B04 · A3 (autónomo) — Proyecto: diseño de la Célula-07
#
# **Actividad evaluable (RA4-d).** 2 h. Diseña la célula robotizada completa.
#
# > Apóyate en los [apuntes](../apuntes.md) (S3).

# %% [markdown]
# ## 1. La tarea
#
# Coger una pieza de **1,5 kg** de un transportador y colocarla a **700 mm**, con repetibilidad **±0,1 mm**.

# %%
pieza, pinza, cables = 1.5, 0.5, 0.2
necesario = pieza + pinza + cables
print("payload necesario (con EOAT):", necesario, "kg")
# TODO: filtra un catalogo de robots y elige uno
...

# %% [markdown]
# ## 2. Seguridad
#
# ¿Comparte espacio con personas? Decide entre **aplicación colaborativa** (ISO 10218:2025) o **vallado**, y justifica.

# %%
# TODO: completa la decision de seguridad
decision = "..."
print(decision)

# %% [markdown]
# ## 3. Verificación en simulación
#
# Comprueba que la trayectoria no cruza una **singularidad** (codo estirado). Si la cruza, cambia el *layout*.

# %%
# TODO: con roboticstoolbox, comprueba el determinante del jacobiano a lo largo de una trayectoria
...

# %% [markdown]
# ## 4. Célula 4.0
#
# Propón PLC, telemetría (OPC UA/MQTT) y un uso del **gemelo digital**.

# %%
# TODO: describe la arquitectura de la celula 4.0
...

# %% [markdown]
# ## 5. Memoria (1 página, entregable)
#
# Estructura: **tarea → criterios → selección → seguridad → riesgos**.

# %%
memoria = """
# Memoria Celula-07
## Tarea
...
## Criterios y seleccion
...
## Seguridad
...
## Riesgos
...
"""
print(memoria)
